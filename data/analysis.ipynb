# %%
import pandas as pd
import re
import warnings
warnings.filterwarnings("ignore")


import sys 
an = sys.path.append("/src/analysis.py")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\ironhack\proyectos\_proy4\data\analysis.ipynb Cell 1 in <cell line: 9>()
#       <a href='vscode-notebook-cell:/d%3A/ironhack/proyectos/_proy4/data/analysis.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a> import sys
#       <a href='vscode-notebook-cell:/d%3A/ironhack/proyectos/_proy4/data/analysis.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a> sys.path.append("/src/analysis.py")
# ----> <a href='vscode-notebook-cell:/d%3A/ironhack/proyectos/_proy4/data/analysis.ipynb#W0sZmlsZQ%3D%3D?line=8'>9</a> import analysis as an
#
# ModuleNotFoundError: No module named 'analysis'

# %%
salud y contaminacion
worldbank.com para salud
income companies.
# Out:
#   Input In [5]
#     salud y contaminacion
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# IMPORT supermarket

# %%
super = pd.read_csv("D:\ironhack\proyectos\_proy4\csv\Supermart_Grocery_Sales.csv")
super
# Out:
#      Order ID Customer Name           Category      Sub Category         City  \
# 0         OD1        Harish       Oil & Masala           Masalas      Vellore
# 1         OD2         Sudha          Beverages     Health Drinks  Krishnagiri
# 2         OD3       Hussain        Food Grains      Atta & Flour   Perambalur
# 3         OD4       Jackson   Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4         OD5       Ridhesh        Food Grains   Organic Staples         Ooty
# ...       ...           ...                ...               ...          ...
# 9989   OD9990        Sudeep  Eggs, Meat & Fish              Eggs      Madurai
# 9990   OD9991          Alan             Bakery          Biscuits  Kanyakumari
# 9991   OD9992          Ravi        Food Grains              Rice         Bodi
# 9992   OD9993          Peer       Oil & Masala            Spices   Pudukottai
# 9993   OD9994        Ganesh        Food Grains      Atta & Flour  Tirunelveli
#
#       Order Date Region  Sales  Discount  Profit       State
# 0     11-08-2017  North   1254      0.12  401.28  Tamil Nadu
# 1     11-08-2017  South    749      0.18  149.80  Tamil Nadu
# 2     06-12-2017   West   2360      0.21  165.20  Tamil Nadu
# 3     10-11-2016  South    896      0.25   89.60  Tamil Nadu
# 4     10-11-2016  South   2355      0.26  918.45  Tamil Nadu
# ...          ...    ...    ...       ...     ...         ...
# 9989  12/24/2015   West    945      0.16  359.10  Tamil Nadu
# 9990  07-12-2015   West   1195      0.26   71.70  Tamil Nadu
# 9991  06-06-2017   West   1567      0.16  501.44  Tamil Nadu
# 9992  10/16/2018   West   1659      0.15  597.24  Tamil Nadu
# 9993   4/17/2018   West   1034      0.28  165.44  Tamil Nadu
#
# [9994 rows x 11 columns]

# %% [markdown]
# IMPORT Food emissin data set.

# %%
food_emisions = pd.read_csv("D:\ironhack\proyectos\_proy4\csv\Food_emissions.csv")
food_emisions.sample()
# Out:
#    Food product  Land use change  Animal Feed  Farm  Processing  Transport  \
# 20     Tomatoes              0.4          0.0   0.7         0.0        0.2
#
#     Packging  Retail  Total_emissions  \
# 20       0.1     0.0              1.4
#
#     Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)  ...  \
# 20                                          39.526316         ...
#
#     Freshwater withdrawals per 100g protein (liters per 100g protein)  \
# 20                                        3361.818182
#
#     Freshwater withdrawals per kilogram (liters per kilogram)  \
# 20                                              369.8
#
#     Greenhouse gas emissions per 1000kcal (kgCO₂eq per 1000kcal)  \
# 20                                               11.0
#
#     Greenhouse gas emissions per 100g protein (kgCO₂eq per 100g protein)  \
# 20                                               19.0
#
#     Land use per 1000kcal (m² per 1000kcal)  \
# 20                                 4.210526
#
#     Land use per kilogram (m² per kilogram)  \
# 20                                      0.8
#
#     Land use per 100g protein (m² per 100g protein)  \
# 20                                         7.272727
#
#     Scarcity-weighted water use per kilogram (liters per kilogram)  \
# 20                                             5335.7
#
#     Scarcity-weighted water use per 100g protein (liters per 100g protein)  \
# 20                                        48506.36364
#
#     Scarcity-weighted water use per 1000kcal (liters per 1000 kilocalories)
# 20                                        28082.63158
#
# [1 rows x 23 columns]

# %%
# Drop not necesary columns. 
food_emisions = food_emisions.drop(columns=["Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)", "Eutrophying emissions per 100g protein (gPO₄eq per 100 grams protein)",
"Freshwater withdrawals per 1000kcal (liters per 1000kcal)", "Freshwater withdrawals per 100g protein (liters per 100g protein)",
"Greenhouse gas emissions per 100g protein (kgCO₂eq per 100g protein)", "Land use per 1000kcal (m² per 1000kcal)", "Land use per 100g protein (m² per 100g protein)",
"Scarcity-weighted water use per 100g protein (liters per 100g protein)", "Scarcity-weighted water use per 1000kcal (liters per 1000 kilocalories)"])
food_emisions.sample()
# Out:
#    Food product  Land use change  Animal Feed  Farm  Processing  Transport  \
# 14         Tofu              1.0          0.0   0.5         0.8        0.2
#
#     Packging  Retail  Total_emissions  \
# 14       0.2     0.3              3.0
#
#     Eutrophying emissions per kilogram (gPO₄eq per kilogram)  \
# 14                                                NaN
#
#     Freshwater withdrawals per kilogram (liters per kilogram)  \
# 14                                                NaN
#
#     Greenhouse gas emissions per 1000kcal (kgCO₂eq per 1000kcal)  \
# 14                                                NaN
#
#     Land use per kilogram (m² per kilogram)  \
# 14                                      NaN
#
#     Scarcity-weighted water use per kilogram (liters per kilogram)
# 14                                                NaN

# %%
#Change names of columns.
food_emisions.rename(columns= {"Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)": "Eutrophying emissions (gPO₄eq per 1000kcal)", 
                               "Freshwater withdrawals per kilogram (liters per kilogram)":"Freshwater withdrawals (liters per kilogram)", 
                               "Greenhouse gas emissions per 1000kcal (kgCO₂eq per 1000kcal)":"Greenhouse gas emissions (kgCO₂eq per 1000kcal)",
                               "Land use per kilogram (m² per kilogram)":"Land use (m² per kilogram)", 
                               "Scarcity-weighted water use per kilogram (liters per kilogram)":"Scarcity-weighted water use (liters per kilogram)"
                               }, inplace = True)

# %%
print(list(food_emisions["Food product"]))
# Out:
# ['Wheat & Rye (Bread)', 'Maize (Meal)', 'Barley (Beer)', 'Oatmeal', 'Rice', 'Potatoes', 'Cassava', 'Cane Sugar', 'Beet Sugar', 'Other Pulses', 'Peas', 'Nuts', 'Groundnuts', 'Soymilk', 'Tofu', 'Soybean Oil', 'Palm Oil', 'Sunflower Oil', 'Rapeseed Oil', 'Olive Oil', 'Tomatoes', 'Onions & Leeks', 'Root Vegetables', 'Brassicas', 'Other Vegetables', 'Citrus Fruit', 'Bananas', 'Apples', 'Berries & Grapes', 'Wine', 'Other Fruit', 'Coffee', 'Dark Chocolate', 'Beef (beef herd)', 'Beef (dairy herd)', 'Lamb & Mutton', 'Pig Meat', 'Poultry Meat', 'Milk', 'Cheese', 'Eggs', 'Fish (farmed)', 'Shrimps (farmed)']

# %% [markdown]
# IMPORT Area data set.

# %%
area = pd.read_csv("D:\ironhack\proyectos\_proy4\csv\\area_harvested.csv", engine="python", error_bad_lines=False)
area.sample()
# Out:
#      Domain Code                        Domain  Area Code (M49)  \
# 9439         QCL  Crops and livestock products              408
#
#                                        Area  Element Code         Element  \
# 9439  Democratic People's Republic of Korea          5312  Area harvested
#
#       Item Code (CPC)    Item  Year Code  Year Unit  Value
# 9439           1341.0  Apples       2020  2020   ha  70787

# %% [markdown]
# ['Wheat & Rye (Bread)', 'Maize (Meal), 'Cassava', 'Cane Sugar', 'Beet Sugar', , 'Peas', 'Nuts', 'Groundnuts', 'Soymilk', 'Tofu', 'Soybean Oil', 'Palm Oil', 'Sunflower Oil', 'Rapeseed Oil', 'Olive Oil', , 'Onions & Leeks', , 'Brassicas', 'Other Vegetables',, 'Beef (beef herd)', 'Beef (dairy herd)', 'Lamb & Mutton', 'Pig Meat', 'Poultry Meat', 'Milk', 'Cheese', 'Eggs', 'Fish (farmed)', 'Shrimps (farmed)']

# %%
import re
# Clean with regex column "Items" to match other Data Frames.
for index, row in area.iterrows():
    re.sub("n\.e\.c\.", "", row[3])
    re.sub(".*Other berries and fruits of the genus vaccinium.*", 'Berries & Grapes', row[3])
    re.sub('.*Onions and shallots, green*.', 'Onions & Leeks', row[3])
    re.sub(".*Beer of barley, malted*.", 'Barley (Beer)', row[3])
    re.sub(".*Barley*.", 'Barley (Beer)', row[3])
    re.sub('.*Brazil nuts, in shell*.', 'Nuts', row[3])
    re.sub(".*Cocoa beans*.", "Chocolate", row[3])
    re.sub('.*Coffee,green*.', "Coffee", row[3])
    re.sub('.*Groundnuts,excluding shelled*.', "Coffee", row[3])
    re.sub('.*Edible roots and tubers with high starch or inulin content,, fresh*.', 'Root Vegetables', row[3])
    re.sub('.*Oats*.', "Oatmeal", row[3])
    re.sub('.*Other citrus fruit,*.', 'Citrus Fruit', row[3])
    re.sub('.*Other fruits*.', 'Other Fruit', row[3])
    re.sub('.*Meat of pig with the bome, fresh or chilled', "Pig", row[3])
    re.sub('.*Meat of cattle with the bone, fresh or chilled', 'Beef', row[3])

# %%
for index, row in area.iterrows():
    re.sub("(n\.e\.c\.)", "", row[3])

# %%
print(set(area["Item"]))
# Out:
# {'Maize (corn)', 'Peas, dry', 'Sugar cane', 'Other citrus fruit, n.e.c.', 'Other vegetables, fresh n.e.c.', 'Edible roots and tubers with high starch or inulin content, n.e.c., fresh', 'Soya beans', 'Barley', 'Grapes', 'Coffee, green', 'Other pulses n.e.c.', 'Apples', 'Walnuts, in shell', 'Groundnuts, excluding shelled', 'Oats', 'Sugar beet', 'Tomatoes', 'Onions and shallots, green', 'Cocoa beans', 'Hazelnuts, in shell', 'Rice', 'Other fruits, n.e.c.', 'Wheat', 'Bananas', 'Potatoes'}

# %%
# iterate 2010
_2010 = {index:[row[6],row[1],row[3]] for index, row in area.iterrows() if row[4] == 2010}
df2010 = pd.DataFrame.from_dict(_2010, orient="index")
df2010.rename(columns= {0: 2010, 1:"Area", 2:"Item"}, inplace = True)

# %%
# iterate 2011
_2011 = {index:[row[6],row[1],row[3]] for index, row in area.iterrows() if row[4] == 2011}
df2011 = pd.DataFrame.from_dict(_2011, orient="index")
df2011.rename(columns= {0: 2011, 1:"Area", 2:"Item"}, inplace = True)

# %%
# iterate 2012
_2012 = {index:[row[6],row[1],row[3]] for index, row in area.iterrows() if row[4] == 2012}
df2012 = pd.DataFrame.from_dict(_2012, orient="index")
df2012.rename(columns= {0: 2012, 1:"Area", 2:"Item"}, inplace = True)

# %%
# iterate 2013
_2013 = {index:[row[6],row[1],row[3]] for index, row in area.iterrows() if row[4] == 2013}
df2013 = pd.DataFrame.from_dict(_2013, orient="index")
df2013.rename(columns= {0: 2013, 1:"Area", 2:"Item"}, inplace = True)

# %%
# iterate 2014
_2014 = {index:[row[6],row[1],row[3]] for index, row in area.iterrows() if row[4] == 2014}
df2014 = pd.DataFrame.from_dict(_2014, orient="index")
df2014.rename(columns= {0: 2014, 1:"Area", 2:"Item"}, inplace = True)

# %%
# iterate 2015
_2015 = {index:[row[6],row[1],row[3]] for index, row in area.iterrows() if row[4] == 2015}
df2015 = pd.DataFrame.from_dict(_2015, orient="index")
df2015.rename(columns= {0: 2015, 1:"Area", 2:"Item"}, inplace = True)

# %%
# iterate 2016
_2016 = {index:[row[6],row[1],row[3]] for index, row in area.iterrows() if row[4] == 2016}
df2016 = pd.DataFrame.from_dict(_2016, orient="index")
df2016.rename(columns= {0: 2016, 1:"Area", 2:"Item"}, inplace = True)

# %%
# iterate 2017
_2017 = {index:[row[6],row[1],row[3]] for index, row in area.iterrows() if row[4] == 2017}
df2017 = pd.DataFrame.from_dict(_2017, orient="index")
df2017.rename(columns= {0: 2017, 1:"Area", 2:"Item"}, inplace = True)

# %%
# iterate 2018
_2018 = {index:[row[6],row[1],row[3]] for index, row in area.iterrows() if row[4] == 2018}
df2018 = pd.DataFrame.from_dict(_2018, orient="index")
df2018.rename(columns= {0: 2018, 1:"Area", 2:"Item"}, inplace = True)

# %%
# iterate 2019
_2019 = {index:[row[6],row[1],row[3]] for index, row in area.iterrows() if row[4] == 2019}
df2019 = pd.DataFrame.from_dict(_2019, orient="index")
df2019.rename(columns= {0: 2019, 1:"Area", 2:"Item"}, inplace = True)

# %%
# iterate 2020
_2020 = {index:[row[6],row[1],row[3]] for index, row in area.iterrows() if row[4] == 2020}
df2020 = pd.DataFrame.from_dict(_2020, orient="index")
df2020.rename(columns= {0: 2020, 1:"Area", 2:"Item"}, inplace = True)

# %%
# iterate 2021
_2021 = {index:[row[6],row[1],row[3]] for index, row in area.iterrows() if row[4] == 2021}
df2021 = pd.DataFrame.from_dict(_2021, orient="index")
df2021.rename(columns= {0: 2021, 1:"Area", 2:"Item"}, inplace = True)

# %%
# Drop columns.
area.drop(columns=["Domain", "Element", "Year", "Unit", "Value"],inplace=True)

# %%
# drop duplicates.
area.drop_duplicates(inplace=True)

# %%
# Merge all df from diferent years to production.
area = pd.DataFrame.merge(area, df2010, how="left")
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# d:\ironhack\proyectos\_proy4\data\analysis.ipynb Cell 32 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/ironhack/proyectos/_proy4/data/analysis.ipynb#Y144sZmlsZQ%3D%3D?line=0'>1</a> # Merge all df from diferent years to production.
# ----> <a href='vscode-notebook-cell:/d%3A/ironhack/proyectos/_proy4/data/analysis.ipynb#Y144sZmlsZQ%3D%3D?line=1'>2</a> area = pd.DataFrame.merge(area, df2010, how="left")
#
# File c:\Users\ima_n\miniconda2\envs\ironhack\lib\site-packages\pandas\core\frame.py:10090, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10071 @Substitution("")
#   10072 @Appender(_merge_doc, indents=2)
#   10073 def merge(
#    (...)
#   10086     validate: str | None = None,
#   10087 ) -> DataFrame:
#   10088     from pandas.core.reshape.merge import merge
# > 10090     return merge(
#   10091         self,
#   10092         right,
#   10093         how=how,
#   10094         on=on,
#   10095         left_on=left_on,
#   10096         right_on=right_on,
#   10097         left_index=left_index,
#   10098         right_index=right_index,
#   10099         sort=sort,
#   10100         suffixes=suffixes,
#   10101         copy=copy,
#   10102         indicator=indicator,
#   10103         validate=validate,
#   10104     )
#
# File c:\Users\ima_n\miniconda2\envs\ironhack\lib\site-packages\pandas\core\reshape\merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
#     121         indicator=indicator,
#     122         validate=validate,
#     123     )
#     124     return op.get_result(copy=copy)
#
# File c:\Users\ima_n\miniconda2\envs\ironhack\lib\site-packages\pandas\core\reshape\merge.py:685, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     681     # stacklevel chosen to be correct when this is reached via pd.merge
#     682     # (and not DataFrame.join)
#     683     warnings.warn(msg, FutureWarning, stacklevel=find_stack_level())
# --> 685 self.left_on, self.right_on = self._validate_left_right_on(left_on, right_on)
#     687 cross_col = None
#     688 if self.how == "cross":
#
# File c:\Users\ima_n\miniconda2\envs\ironhack\lib\site-packages\pandas\core\reshape\merge.py:1434, in _MergeOperation._validate_left_right_on(self, left_on, right_on)
#    1432 common_cols = left_cols.intersection(right_cols)
#    1433 if len(common_cols) == 0:
# -> 1434     raise MergeError(
#    1435         "No common columns to perform merge on. "
#    1436         f"Merge options: left_on={left_on}, "
#    1437         f"right_on={right_on}, "
#    1438         f"left_index={self.left_index}, "
#    1439         f"right_index={self.right_index}"
#    1440     )
#    1441 if (
#    1442     not left_cols.join(common_cols, how="inner").is_unique
#    1443     or not right_cols.join(common_cols, how="inner").is_unique
#    1444 ):
#    1445     raise MergeError(f"Data columns not unique: {repr(common_cols)}")
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False

# %%
area = pd.DataFrame.merge(area, df2011, how="left")

# %%
area = pd.DataFrame.merge(area, df2012, how="left")

# %%
area = pd.DataFrame.merge(area, df2013, how="left")

# %%
area = pd.DataFrame.merge(area, df2014, how="left")

# %%
area = pd.DataFrame.merge(area, df2015, how="left")

# %%
area = pd.DataFrame.merge(area, df2016, how="left")

# %%
area = pd.DataFrame.merge(area, df2017, how="left")

# %%
area = pd.DataFrame.merge(area, df2018, how="left")

# %%
area = pd.DataFrame.merge(area, df2019, how="left")

# %%
area = pd.DataFrame.merge(area, df2020, how="left")

# %%
area = pd.DataFrame.merge(area, df2021, how="left")

# %%
# Drop duplicates from item and area columns.
area = area.drop_duplicates(subset=["Item", "Area"])

# %%
area
# Out:
#              Area                        Item      2010      2011      2012  \
# 0     Afghanistan                      Apples    8550.0    8863.0    9148.0
# 1     Afghanistan                      Barley  212000.0  190000.0  280000.0
# 2     Afghanistan                      Grapes   61132.0   61558.0   61690.0
# 3     Afghanistan                Maize (corn)  183000.0  183000.0  141000.0
# 4     Afghanistan  Other citrus fruit, n.e.c.     200.0     200.0     200.0
# ...           ...                         ...       ...       ...       ...
# 2920     Zimbabwe                        Rice    1543.0    1911.0    2833.0
# 2921     Zimbabwe                  Soya beans   42288.0   44672.0   50408.0
# 2922     Zimbabwe                  Sugar cane   40663.0   42828.0   53486.0
# 2923     Zimbabwe                    Tomatoes    3200.0    3146.0    3300.0
# 2924     Zimbabwe                       Wheat    6478.0    8645.0   21377.0
#
#           2013      2014      2015      2016      2017     2018     2019  \
# 0      10341.0   12247.0   13038.0   19365.0   26847.0  28381.0  27559.0
# 1     278000.0  342472.0  282000.0  219208.0   68179.0  84147.0  84070.0
# 2      62118.0   78405.0   78681.0   82450.0   87194.0  87517.0  89593.0
# 3     142000.0  127000.0  147273.0  151900.0  134225.0  72433.0  94910.0
# 4        300.0     300.0     300.0    1662.0    1643.0   1700.0   3391.0
# ...        ...       ...       ...       ...       ...      ...      ...
# 2920    2960.0    3755.0    4626.0    3780.0    3543.0   3371.0   2529.0
# 2921   50785.0   60616.0   44155.0   39935.0   23515.0  37307.0  33136.0
# 2922   46605.0   43121.0   43094.0   43500.0   41000.0  45000.0  46000.0
# 2923    3300.0    3370.0    3508.0    3498.0    3481.0   3602.0   3607.0
# 2924   21753.0   18059.0   22114.0   22094.0   22070.0  16700.0  24186.0
#
#           2020     2021
# 0      25643.0  26540.0
# 1      86099.0  84072.0
# 2      92584.0  96560.0
# 3     140498.0  92144.0
# 4        449.0   1403.0
# ...        ...      ...
# 2920    1260.0   3466.0
# 2921   32874.0  34648.0
# 2922   47000.0  47000.0
# 2923    3564.0   3591.0
# 2924   44466.0  66434.0
#
# [2925 rows x 14 columns]

# %% [markdown]
# ['Wheat & Rye (Bread)', 'Maize (Meal)', 'Barley (Beer)', 'Oatmeal', 'Rice', 'Potatoes', 'Cassava', 'Cane Sugar', 'Beet Sugar', 'Other Pulses', 'Peas', 'Nuts', 'Groundnuts', 'Soymilk', 'Tofu', 'Soybean Oil', 'Palm Oil', 'Sunflower Oil', 'Rapeseed Oil', 'Olive Oil', 'Tomatoes', 'Onions & Leeks', 'Root Vegetables', 'Brassicas', 'Other Vegetables', 'Citrus Fruit', 'Bananas', 'Apples', 'Berries & Grapes', 'Wine', 'Other Fruit', 'Coffee', 'Dark Chocolate', 'Beef (beef herd)', 'Beef (dairy herd)', 'Lamb & Mutton', 'Pig Meat', 'Poultry Meat', 'Milk', 'Cheese', 'Eggs', 'Fish (farmed)', 'Shrimps (farmed)']

# %% [markdown]
# IMPORT quantity data set.

# %%
production = pd.read_csv("D:\ironhack\proyectos\_proy4\csv\\production_quantity.csv")
production.sample()
# Out:
#      Domain Code                        Domain  Area Code (M49)      Area  \
# 9154         QCL  Crops and livestock products              116  Cambodia
#
#       Element Code     Element  Item Code (CPC)          Item  Year Code  \
# 9154          5510  Production            112.0  Maize (corn)       2019
#
#       Year    Unit     Value
# 9154  2019  tonnes  895000.0

# %%
# Drop columns.
production.drop(columns=["Domain", "Domain Code", "Element Code", "Element", "Year Code"],inplace=True)

# %%
production
# Out:
#        Area Code         Area  Item Code    Item  Year    Unit     Value
# 0              4  Afghanistan    1341.00  Apples  2008  tonnes  56060.69
# 1              4  Afghanistan    1341.00  Apples  2009  tonnes  72765.00
# 2              4  Afghanistan    1341.00  Apples  2010  tonnes  59850.00
# 3              4  Afghanistan    1341.00  Apples  2011  tonnes  62041.00
# 4              4  Afghanistan    1341.00  Apples  2012  tonnes  70000.00
# ...          ...          ...        ...     ...   ...     ...       ...
# 63173        716     Zimbabwe   24212.02    Wine  2009  tonnes   1750.00
# 63174        716     Zimbabwe   24212.02    Wine  2010  tonnes   1750.00
# 63175        716     Zimbabwe   24212.02    Wine  2011  tonnes   1750.00
# 63176        716     Zimbabwe   24212.02    Wine  2012  tonnes   1750.00
# 63177        716     Zimbabwe   24212.02    Wine  2013  tonnes   1750.00
#
# [63178 rows x 7 columns]

# %%
# Change names.
production.rename(columns={"Area Code (M49)":"Area Code", "Item Code (CPC)": "Item Code"}, inplace= True)

# %%
def iterate_column_years (year):
    # iterate 2010
    x = {index:[row[6],row[0],row[2]] for index, row in production.iterrows() if row[4] == year}
    df = pd.DataFrame.from_dict(x, orient="index")
    df.rename(columns= {0: year, 1:"Area", 3:"Item"}, inplace = True)
    df["Item"] = df["Item"].astype(object)
    df["Area"] = df["Area"].astype(object)
    df[year] = df[year].astype(object)
    return df

# %%
# iterate 2010
df2010 = iterate_column_years (2010)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ima_n\miniconda2\envs\ironhack\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\ima_n\miniconda2\envs\ironhack\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\ima_n\miniconda2\envs\ironhack\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Item'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# d:\ironhack\proyectos\_proy4\data\analysis.ipynb Cell 55 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/ironhack/proyectos/_proy4/data/analysis.ipynb#Y103sZmlsZQ%3D%3D?line=0'>1</a> # iterate 2010
# ----> <a href='vscode-notebook-cell:/d%3A/ironhack/proyectos/_proy4/data/analysis.ipynb#Y103sZmlsZQ%3D%3D?line=1'>2</a> df2010 = iterate_column_years (2010)
#
# d:\ironhack\proyectos\_proy4\data\analysis.ipynb Cell 55 in iterate_column_years(year)
#       <a href='vscode-notebook-cell:/d%3A/ironhack/proyectos/_proy4/data/analysis.ipynb#Y103sZmlsZQ%3D%3D?line=3'>4</a> df = pd.DataFrame.from_dict(x, orient="index")
#       <a href='vscode-notebook-cell:/d%3A/ironhack/proyectos/_proy4/data/analysis.ipynb#Y103sZmlsZQ%3D%3D?line=4'>5</a> df.rename(columns= {0: year, 1:"Area", 3:"Item"}, inplace = True)
# ----> <a href='vscode-notebook-cell:/d%3A/ironhack/proyectos/_proy4/data/analysis.ipynb#Y103sZmlsZQ%3D%3D?line=5'>6</a> df["Item"] = df["Item"].astype(object)
#       <a href='vscode-notebook-cell:/d%3A/ironhack/proyectos/_proy4/data/analysis.ipynb#Y103sZmlsZQ%3D%3D?line=6'>7</a> df["Area"] = df["Area"].astype(object)
#       <a href='vscode-notebook-cell:/d%3A/ironhack/proyectos/_proy4/data/analysis.ipynb#Y103sZmlsZQ%3D%3D?line=7'>8</a> df[year] = df[year].astype(object)
#
# File c:\Users\ima_n\miniconda2\envs\ironhack\lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File c:\Users\ima_n\miniconda2\envs\ironhack\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'Item'

# %%
df2010.dtypes
# Out:
# 2010    object
# Area    object
# Item    object
# dtype: object

# %%
# iterate 2011
df2011 = iterate_column_years (2011)

# %%
# iterate 2012
df2012 = iterate_column_years (2012)

# %%
# iterate 2013
df2013 = iterate_column_years (2013)

# %%
# iterate 2014
df2014 = iterate_column_years (2014)

# %%
# iterate 2015
df2015 = iterate_column_years (2015)

# %%
# iterate 2016
df2016 = iterate_column_years (2016)

# %%
# iterate 2017
df2017 = iterate_column_years (2017)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ima_n\miniconda2\envs\ironhack\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\ima_n\miniconda2\envs\ironhack\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\ima_n\miniconda2\envs\ironhack\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Item'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# d:\ironhack\proyectos\_proy4\data\analysis.ipynb Cell 63 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/ironhack/proyectos/_proy4/data/analysis.ipynb#X63sZmlsZQ%3D%3D?line=0'>1</a> # iterate 2017
# ----> <a href='vscode-notebook-cell:/d%3A/ironhack/proyectos/_proy4/data/analysis.ipynb#X63sZmlsZQ%3D%3D?line=1'>2</a> df2017 = iterate_column_years (2017)
#
# d:\ironhack\proyectos\_proy4\data\analysis.ipynb Cell 63 in iterate_column_years(year)
#       <a href='vscode-notebook-cell:/d%3A/ironhack/proyectos/_proy4/data/analysis.ipynb#X63sZmlsZQ%3D%3D?line=3'>4</a> df = pd.DataFrame.from_dict(x, orient="index")
#       <a href='vscode-notebook-cell:/d%3A/ironhack/proyectos/_proy4/data/analysis.ipynb#X63sZmlsZQ%3D%3D?line=4'>5</a> df.rename(columns= {0: year, 1:"Area", 3:"Item"}, inplace = True)
# ----> <a href='vscode-notebook-cell:/d%3A/ironhack/proyectos/_proy4/data/analysis.ipynb#X63sZmlsZQ%3D%3D?line=5'>6</a> df["Item"] = df["Item"].astype(object)
#       <a href='vscode-notebook-cell:/d%3A/ironhack/proyectos/_proy4/data/analysis.ipynb#X63sZmlsZQ%3D%3D?line=6'>7</a> df["Area"] = df["Area"].astype(object)
#       <a href='vscode-notebook-cell:/d%3A/ironhack/proyectos/_proy4/data/analysis.ipynb#X63sZmlsZQ%3D%3D?line=7'>8</a> df[year] = df[year].astype(object)
#
# File c:\Users\ima_n\miniconda2\envs\ironhack\lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File c:\Users\ima_n\miniconda2\envs\ironhack\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'Item'

# %%
# iterate 2018
df2018 = iterate_column_years (2018)

# %%
# iterate 2019
df2019 = iterate_column_years (2019)

# %%
# iterate 2020
df2020 = iterate_column_years (2020)

# %%
# iterate 2021
df2021 = iterate_column_years (2021)

# %%
# Drop columns.
production.drop(columns=["Year", "Value", "Unit"],inplace=True)

# %%
production.sample()
# Out:
#       Area Code        Area  Item Code                        Item  Year  \
# 4004         50  Bangladesh   22251.01  Cheese from whole cow milk  2018
#
#         Unit    Value
# 4004  tonnes  1147.15

# %%
production["Item Code"] = production["Item Code"].astype(object)

# %%
production["Area Code"] = production["Area Code"].astype(object)

# %%
# drop duplicates.
production.drop_duplicates(inplace=True)

# %%
df2010
# Out:
#             2010 Area      Item
# 2        59850.0    4    1341.0
# 16      437000.0    4     115.0
# 30      397000.0    4    1330.0
# 44       16344.0    4     231.0
# 58      326880.0    4     231.0
# ...          ...  ...       ...
# 63119  2692000.0  716    1802.0
# 63133     3800.0  716  21631.01
# 63146    25000.0  716    1234.0
# 63160    18000.0  716     111.0
# 63174     1750.0  716  24212.02
#
# [4538 rows x 3 columns]

# %%
# Merge all df from diferent years to production.
production = pd.DataFrame.merge(production, df2010, on= "Item", how="left")

# %%
production
# Out:
#      Area Code       Area_x Item Code                       Item 2010_x  \
# 0            4  Afghanistan    1341.0                     Apples    NaN
# 1            4  Afghanistan     115.0                     Barley    NaN
# 2            4  Afghanistan    1330.0                     Grapes    NaN
# 3            4  Afghanistan     231.0   Hen eggs in shell, fresh    NaN
# 4            4  Afghanistan     112.0               Maize (corn)    NaN
# ...        ...          ...       ...                        ...    ...
# 4536       716     Zimbabwe    1802.0                 Sugar cane    NaN
# 4537       716     Zimbabwe  21631.01  Sunflower-seed oil, crude    NaN
# 4538       716     Zimbabwe    1234.0                   Tomatoes    NaN
# 4539       716     Zimbabwe     111.0                      Wheat    NaN
# 4540       716     Zimbabwe  24212.02                       Wine    NaN
#
#      2010_y Area_y 2010 Area
# 0       NaN    NaN  NaN  NaN
# 1       NaN    NaN  NaN  NaN
# 2       NaN    NaN  NaN  NaN
# 3       NaN    NaN  NaN  NaN
# 4       NaN    NaN  NaN  NaN
# ...     ...    ...  ...  ...
# 4536    NaN    NaN  NaN  NaN
# 4537    NaN    NaN  NaN  NaN
# 4538    NaN    NaN  NaN  NaN
# 4539    NaN    NaN  NaN  NaN
# 4540    NaN    NaN  NaN  NaN
#
# [4541 rows x 9 columns]

# %%
production = pd.DataFrame.merge(production, df2011, on= "Item", how="left")

# %%
production = pd.DataFrame.merge(production, df2012, on= "Item", how="left")

# %%
production = pd.DataFrame.merge(production, df2013, on= "Item", how="left")

# %%
production = pd.DataFrame.merge(production, df2014, how="left")

# %%
production = pd.DataFrame.merge(production, df2015, how="left")

# %%
production = pd.DataFrame.merge(production, df2016, how="left")

# %%
production = pd.DataFrame.merge(production, df2017, how="left")

# %%
production = pd.DataFrame.merge(production, df2018, how="left")

# %%
production = pd.DataFrame.merge(production, df2019, how="left")

# %%
production
# Out:
#       Area Code       Area_x  Item Code                       Item  2010  \
# 0             4  Afghanistan    1341.00                     Apples   NaN
# 1             4  Afghanistan     115.00                     Barley   NaN
# 2             4  Afghanistan    1330.00                     Grapes   NaN
# 3             4  Afghanistan     231.00   Hen eggs in shell, fresh   NaN
# 4             4  Afghanistan     112.00               Maize (corn)   NaN
# ...         ...          ...        ...                        ...   ...
# 4536        716     Zimbabwe    1802.00                 Sugar cane   NaN
# 4537        716     Zimbabwe   21631.01  Sunflower-seed oil, crude   NaN
# 4538        716     Zimbabwe    1234.00                   Tomatoes   NaN
# 4539        716     Zimbabwe     111.00                      Wheat   NaN
# 4540        716     Zimbabwe   24212.02                       Wine   NaN
#
#       Area_y  2011  Area_x  2012  Area_y  2013  Area  2014  2015  2016  2017  \
# 0        NaN   NaN     NaN   NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1        NaN   NaN     NaN   NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2        NaN   NaN     NaN   NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3        NaN   NaN     NaN   NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4        NaN   NaN     NaN   NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...      ...   ...     ...   ...     ...   ...   ...   ...   ...   ...   ...
# 4536     NaN   NaN     NaN   NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4537     NaN   NaN     NaN   NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4538     NaN   NaN     NaN   NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4539     NaN   NaN     NaN   NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4540     NaN   NaN     NaN   NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#       2018  2019
# 0      NaN   NaN
# 1      NaN   NaN
# 2      NaN   NaN
# 3      NaN   NaN
# 4      NaN   NaN
# ...    ...   ...
# 4536   NaN   NaN
# 4537   NaN   NaN
# 4538   NaN   NaN
# 4539   NaN   NaN
# 4540   NaN   NaN
#
# [4541 rows x 18 columns]

# %%
production = pd.DataFrame.merge(production, df2020, how="left")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\ironhack\proyectos\_proy4\data\analysis.ipynb Cell 78 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/ironhack/proyectos/_proy4/data/analysis.ipynb#Y120sZmlsZQ%3D%3D?line=0'>1</a> production = pd.DataFrame.merge(production, df2020, how="left")
#
# File c:\Users\ima_n\miniconda2\envs\ironhack\lib\site-packages\pandas\core\frame.py:10090, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10071 @Substitution("")
#   10072 @Appender(_merge_doc, indents=2)
#   10073 def merge(
#    (...)
#   10086     validate: str | None = None,
#   10087 ) -> DataFrame:
#   10088     from pandas.core.reshape.merge import merge
# > 10090     return merge(
#   10091         self,
#   10092         right,
#   10093         how=how,
#   10094         on=on,
#   10095         left_on=left_on,
#   10096         right_on=right_on,
#   10097         left_index=left_index,
#   10098         right_index=right_index,
#   10099         sort=sort,
#   10100         suffixes=suffixes,
#   10101         copy=copy,
#   10102         indicator=indicator,
#   10103         validate=validate,
#   10104     )
#
# File c:\Users\ima_n\miniconda2\envs\ironhack\lib\site-packages\pandas\core\reshape\merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
#     121         indicator=indicator,
#     122         validate=validate,
#     123     )
#     124     return op.get_result(copy=copy)
#
# File c:\Users\ima_n\miniconda2\envs\ironhack\lib\site-packages\pandas\core\reshape\merge.py:707, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     699 (
#     700     self.left_join_keys,
#     701     self.right_join_keys,
#     702     self.join_names,
#     703 ) = self._get_merge_keys()
#     705 # validate the merge keys dtypes. We may need to coerce
#     706 # to avoid incompatible dtypes
# --> 707 self._maybe_coerce_merge_keys()
#     709 # If argument passed to validate,
#     710 # check if columns specified as unique
#     711 # are in fact unique.
#     712 if validate is not None:
#
# File c:\Users\ima_n\miniconda2\envs\ironhack\lib\site-packages\pandas\core\reshape\merge.py:1340, in _MergeOperation._maybe_coerce_merge_keys(self)
#    1334     # unless we are merging non-string-like with string-like
#    1335     elif (
#    1336         inferred_left in string_types and inferred_right not in string_types
#    1337     ) or (
#    1338         inferred_right in string_types and inferred_left not in string_types
#    1339     ):
# -> 1340         raise ValueError(msg)
#    1342 # datetimelikes must match exactly
#    1343 elif needs_i8_conversion(lk.dtype) and not needs_i8_conversion(rk.dtype):
#
# ValueError: You are trying to merge on object and int64 columns. If you wish to proceed you should use pd.concat

# %%
production = pd.DataFrame.merge(production, df2021, on="Item", how="left")

# %%
production
# Out:
# Empty DataFrame
# Columns: [Area Code, Area_x, Item Code, 2021_x, Area_y, 2021_y, Area_x, 2021, Area_y, Item]
# Index: []

# %%
# Drop duplicates from item and area columns.
production.drop_duplicates(subset=["Item", "Area"])
# Out:
#                Area                      Item       2010       2011  \
# 0       Afghanistan                    Apples   59850.00   62041.00
# 1       Afghanistan                    Barley  437000.00  305900.00
# 2       Afghanistan  Hen eggs in shell, fresh   16344.00   17210.00
# 4098    Afghanistan              Maize (corn)  301000.00  300120.00
# 4099    Afghanistan                 Olive oil     595.68     538.56
# ...             ...                       ...        ...        ...
# 910427     Zimbabwe                  Tomatoes   25000.00   22500.00
# 910428     Zimbabwe                     Wheat   18000.00   23000.00
# 910429     Zimbabwe     Whole milk, condensed     712.95     730.87
# 910430     Zimbabwe    Whole milk, evaporated    4705.49    4823.47
# 910431     Zimbabwe                      Wine    1750.00    1750.00
#
#              2012       2013       2014       2015       2016       2017  \
# 0        70000.00   78597.00   89403.00   89733.00  140903.00  170443.00
# 1       504000.00  514000.00  521000.00  403000.00  301856.00   94995.00
# 2        18000.00   18000.00   18500.00   19833.01   19883.74   20000.00
# 4098    310000.00  312000.00  316000.00  316000.00  311646.00  173912.00
# 4099       538.56     545.93     658.42     711.37     740.90     763.25
# ...           ...        ...        ...        ...        ...        ...
# 910427   23500.00   23500.00   24271.13   25322.84   25318.39   25278.36
# 910428   53231.78   50966.05   40000.00   45302.00   42008.00   38715.00
# 910429     750.55     759.51     776.69     772.13     764.96     739.13
# 910430    4953.61    5012.55    5125.02    5096.70    5049.87    4878.27
# 910431    1750.00    1750.00        NaN        NaN        NaN        NaN
#
#              2018       2019       2020       2021
# 0       217192.00  250324.00  270857.00  292586.58
# 1        56781.00  123576.00  127757.00  122692.77
# 2        19905.58   22040.18   22039.10   22248.74
# 4098    106670.00  184671.00  271776.00  180000.00
# 4099       812.16     833.25     821.31        NaN
# ...           ...        ...        ...        ...
# 910427   25306.53   25301.09   25295.33   25300.98
# 910428   45000.00   94685.00  212530.00  337212.00
# 910429     746.84     759.12     759.00        NaN
# 910430    4929.81    5010.21    5009.42        NaN
# 910431        NaN        NaN        NaN        NaN
#
# [4111 rows x 14 columns]

# %% [markdown]
# IMPORT production.

# %%
price= pd.read_csv("D:\ironhack\proyectos\_proy4\csv\\producer_price.csv")
price.sample()
# Out:
#       Domain Code           Domain  Area Code (M49)  \
# 30431          PP  Producer Prices              670
#
#                                    Area  Element Code  \
# 30431  Saint Vincent and the Grenadines          5532
#
#                           Element Item Code (CPC)          Item  Year Code  \
# 30431  Producer Price (USD/tonne)            0112  Maize (corn)       2008
#
#        Year  Months Code        Months Unit   Value Flag Flag Description
# 30431  2008         7021  Annual value  USD  1486.1    A  Official figure

# %%
price.drop(columns= ["Domain Code", "Domain", ])
